# %% [markdown]
# # Vector representation of DeCS codes

# %% [markdown]
# Primero hay que descargar los dataset con el script `get_data.py` que está en la raíz del repositorio.

# %%
import sys
sys.path.append("..")
import mesinesp2.tokenizer

# %% [markdown]
# Cargamos un diccionario con todos los códigos DeCS

# %%
descriptions = mesinesp2.tokenizer.get_descriptions("../data/raw/DeCS2020.obo", tokenize_definition = False, tokenize_name = False)
decs = {}
for key,val in descriptions.items():
    if key.startswith("D"):
        code = key
        document = val["name"]
        if "def" in val:
            document = document + " " + val["def"]
        decs[code] = document

# %%
decs
# Out:
# {'DeCS': 'DeCS',
#  'D': 'COMPUESTOS QUÍMICOS Y DROGAS',
#  'D000001': 'Calcimicina Un antibiótico poliéter, ionóforo, de Streptomyces chartreusensis. Se une y transporta cationes a través de las membranas y desacopla la fosforilación oxidativa mientras inhibe la ATPasa de la mitocondria hepática del ratón. Esta sustancia es utilizada principalmente como herramienta bioquímica para estudiar el papel de los cationes divalentes en varios sistemas biológicos.',
#  'D000002': 'Temefós Un insecticida organotiofosforado.',
#  'D000003': 'Mataderos Lugares donde los animales son sacrificados y preparados para el mercado.',
#  'D000004': 'Abreviaturas como Asunto 1. f. Abreviación gráfica formada por el conjunto de letras iniciales de una expresión compleja; p. ej., ONU por Organización de las Naciones Unidas, ovni por objeto volador no identificado, IPC por índice de precios al consumo. 2. f. Cada una de las letras de una sigla (‖ abreviación formada por letras iniciales). P. ej., O, N y U son siglas en ONU. 3. f. Cualquier signo que sirve para ahorrar letras o espacio en la escritura. (Fuente: Diccionario de la Real Academia Española. Disponible en: https://dle.rae.es/?id=XqwEQdl)',
#  'D000005': 'Abdomen Porción del cuerpo que se encuentra entre el TÓRAX y la PELVIS.',
#  'D000006': 'Abdomen Agudo Síndrome clínico caracterizado por dolor abdominal intenso, localizado y de inicio rápido. El abdomen agudo puede ser resultado de diversos trastornos, lesiones o enfermedades.',
#  'D000007': 'Traumatismos Abdominales Lesión general o inespecífica en la que participan órganos de la cavidad abdominal.',
#  'D000008': 'Neoplasias Abdominales Crecimiento anormal nuevo de tejido en el ABDOMEN.',
#  'D000009': 'Músculos Abdominales Músculos que forman la PARED ABDOMINAL incluyendo el RECTO DEL ABDOMEN; los MÚSCULOS OBLICUOS DEL ABDOMEN, los músculos transverso abdominal, músculos piramidales y los músculos cuadrados lumbares.',
#  'D000010': 'Nervio Abducens Sexto nervio craneal, el cual se origina en el NÚCLEO DEL NERVIO ABDUCENS del PUENTE y envía fibras motoras a los músculos rectos laterales del OJO. El daño del nervio o su núcleo interrumpe el control del movimiento horizontal del ojo.',
#  'D000011': 'Virus de la Leucemia Murina de Abelson Una cepa de VIRUS DE LA LEUCEMIA MURINA con defecto para replicación capaz de transformar a las células linfoides y producir una leucemia linfoide rápidamente progresiva luego de la superinfección con VIRUS DE LA LEUCEMIA MURINA DE FRIEND, VIRUS DE LA LEUCEMIA MURINA DE MOLONEY, o VIRUS RAUSCHER.',
#  'D000012': 'Abetalipoproteinemia Trastorno del metabolismo lipídico que se hereda como rasgo autosómico recesivo y que se caracteriza por la ausencia casi total en el plasma de APOLIPOPROTEÍNAS B y de lipoproteínas que contienen apoB. La proteína que transfiere los triglicéridos microsomales es deficiente o está ausente en los enterocitos. Los hallazgos clínicos y de laboratorio incluyen acantocitosis, hipocolesterolemia, neuropatía periférica, degeneración columnar posterior, ataxia, y esteatorrea. Las capacidades intelectuales también pueden estar afectadas.',
#  'D000013': 'Anomalías Congénitas Malformaciones de órganos o partes del cuerpo durante el desarrollo intrauterino.',
#  'D000014': 'Anomalías Inducidas por Medicamentos Anomalías congénitas producidas por sustancias medicinales o por abuso de drogas dadas o tomadas por la madre, o a las cuales se expone inadvertidamente durante la producción de dichas sustancias. El concepto excluye las anomalías que se producen por exposición a productos químicos no medicinales en el medio ambiente.',
#  'D000015': 'Anomalías Múltiples Anomalías congénitas que afectan a más de un órgano o estructura corporal.',
#  'D000016': 'Anomalías Inducidas por Radiación Cambios congénitos en la morfología de órganos, producidos por exposición a la radiación ionizante y no ionizante.',
#  'D000017': 'Sistema del Grupo Sanguíneo ABO Principal sistema de tipos sanguíneos humanos que depende de la presencia o ausencia de dos antígenos A y B. El tipo O ocurre cuando no está presente ni el A ni el B y AB cuando ambos estén presentes. A y B son factores genéticos que determina la presencia de enzimas para la síntesis de ciertas glicoproteínas principalmente en la membrana de los hematíes.',
#  'D000018': 'Abomaso Cuarto estómago de los animales rumiantes. También se conoce como el estómago "verdadero". Es un saco elongado en forma de pera que yace sobre el suelo del abdomen, sobre el lado derecho, y aproximadamente entre la séptima y la duodécima costilla. Lleva al comienzo del intestino delgado. (Traducción libre del original: Black\'s Veterinary Dictionary, 17 ed)',
#  'D000019': 'Abortivos Sustancias químicas que interrumpen el embarazo tras la implantación.',
#  'D000020': 'Abortivos no Esteroideos Compuestos químicos no esteroideos con actividad abortiva.',
#  'D000021': 'Abortivos Esteroideos Compuestos esteroideos con actividad abortiva.',
#  'D000022': 'Aborto Espontáneo Expulsión del producto de la FERTILIZACIÓN antes de completar el término de la GESTACIÓN y sin interferencia deliberada.',
#  'D000023': 'Solicitantes de Aborto Individuos que solicitan abortos inducidos.',
#  'D000024': 'Aborto Criminal Interrupción ilegal del embarazo.',
#  'D000025': 'Aborto Eugénico Aborto realizado por posibles defectos fetales.',
#  'D000026': 'Aborto Habitual Tres o más abortos espontáneos.',
#  'D000027': 'Aborto Incompleto Interrupción prematura del EMBARAZO, en el que no todos los productos de la CONCEPCIÓN han sido expulsados.',
#  'D000028': 'Aborto Inducido Remoción intencional de un feto del útero mediante cualquiera de las numerosas técnicas. Tasa de abortos: Número estimado de abortos por cada mil mujeres con edad comprendida entre 15 y 44 años en determinado año. (Traducción libre del original: Popline, 2002)',
#  'D000029': 'Aborto Legal Interrupción del embarazo bajo condiciones permitidas por la legislación local.',
#  'D000030': 'Aborto Retenido Retención en el ÚTERO de un FETO muerto dos meses o más después de su MUERTE.',
#  'D000031': 'Aborto Séptico Cualquier tipo de aborto, inducido o espontáneo, que se asocia con infección del ÚTERO y sus anexos. Se caracteriza por FIEBRE, blandura uterina y supuración fétida.',
#  'D000032': 'Aborto Terapéutico Aborto provocado para salvar la vida o la salud (física o mental) de una enbarazada; a veces se efectúa después de la violación o incesto. (Dorland, 28a ed)',
#  'D000033': 'Amenaza de Aborto HEMORRAGIA UTERINA en una GESTACIÓN de menos de 20 semanas sin DILATACIÓN CERVICAL. Se caracteriza por hemorragia vaginal, molestia inferior posterior o calambres pélvicos mediales y es un factor de riesgo de ABORTO ESPONTÁNEO.',
#  'D000034': 'Aborto Veterinario Expulsión prematura del FETO en animales.',
#  'D000035': 'Abreacción Proceso en psicoterapia en la que el paciente es "desensibilizado" a emociones dolorosas, a menudo recuerdos olvidados (reprimidos), recordando y reaccionando a ellos en la "seguridad" del tratamiento configurado.',
#  'D000036': 'Abrina Lectina tóxica que proviene de las semillas del gayruro, Abrus precatorius L. Es un veneno muy activo. Hasta el momento se han aislado cinco proteínas diferentes: Abrus aglutinina, que es el componente responsable de la actividad hemaglutinante y abrinas a-d, que son los principios tóxicos constituidos cada uno por dos cadenas de péptidos que se mantienen unidas por enlaces disulfuro.',
#  'D000037': 'Desprendimiento Prematuro de la Placenta Separación prematura de una PLACENTA que está normalmente implantada en el ÚTERO. Presenta signos de diferente grado de severidad, incluyendo HEMORRAGIA UTERINA, HIPERTONIA MUSCULAR uterina y SUFRIMIENTO FETAL o MUERTE FETAL.',
#  'D000038': 'Absceso Acumulación de material purulento en los tejidos, órganos o espacios circunscritos, asociado usualmente con signos de infección.',
#  'D000039': 'Absceso Peritonsilar Una acumulación de material purulento en la zona comprendida entre la TONSILA PALATINA y su cápsula.',
#  'D000040': 'Ácido Abscísico Sustancia de crecimiento aceleradora de la abscisión asilada del fruto del algodón joven, hojas de sicomoro, abedul y otras plantas así como de las papas, limones, aguacates y otras frutas.',
#  'D000041': 'Absentismo Ausencia al trabajo u otras obligaciones.',
#  'D000042': 'Absorción Procesos físicos o fisiológicos por los cuales las sustancias, tejidos, células, etc. absorben o asimilan otras sustancias o energía.',
#  'D000043': 'Indización y Redacción de Resúmenes Trabajos sobre actividades realizadas para identificar conceptos y aspectos de información publicada e informes de investigación.',
#  'D000044': 'Pilares Dentales Dientes naturales o raíces de dientes utilizados como anclajes para una dentadura fija o removible o para otras prótesis (por ejemplo un implante) que tienen el mismo propósito.',
#  'D000045': 'Acacia Género de planta de la familia FABACEAE. Las gomas y los agentes curtientes obtenidos de Acacia se llaman GOMA ARÁBIGA. El nombre común catechu se usa más a menudo para Areca catechu (ARECA).',
#  'D000046': 'Centros Médicos Académicos Complejos médicos que constan de escuela de medicina, hospitales, clínicas, bibiotecas, instalaciones administrativas, etc.',
#  'D000047': 'Academias e Institutos Organizaciones representando áreas especializadas que son reconocidas y autorizadas. Pueden ser no gubernamentales, universidades u organizaciones de investigación independientes; por ejemplo, Academia Nacional de Ciencias etc.',
#  'D000048': 'Acanthamoeba Género de amebas terrestres de vida libre que no tiene etapa flagelada. Sus organismos son patógenos para varias infecciones en humanos y se han encontrado en el ojo, huesos, cerebro y tracto respiratorio.',
#  'D000049': 'Acantocéfalos Filo de lombrices parásitas, íntimamente relacionadas a las tenias y que contienen dos géneros: Moniliformis que en ocasiones infestan al hombre, y Macracanthorhynchus, que infectan a los cerdos.',
#  'D000050': 'Acantocitos Eritrocitos con proyecciones protoplasmáticas que le confieren a la célula un aspecto espinoso.',
#  'D000051': 'Acantólisis Separación de las células del estrato espinoso de la epidermis que producen atrofia de dicha capa celular. Se observa en enfermedades como el pénfigo vulgar (ver PENFIGO) y ENFERMEDAD DE DARIER.',
#  'D000052': 'Acantosis Nigricans Melanosis circunscrita que está constituida por una verrugosidad aterciopelada de color carmelitoso o papilomatosis fina que aparece en las axilas o en otros pliegues del cuerpo. Ocurre en asociación con trastornos endocrinos, enfermedades malignas, administración de ciertos medicamentos, o como trastorno hereditario.',
#  'D000053': 'Ácaros y Garrapatas Subclase grande de arácnidos que comprenden los ácaros y las garrapatas, y que incluyen parásitos de plantas, animales y del hombre, así como varios vectores de enfermedades importantes.',
#  'D000054': 'Aceleración 1) Un aumento en la tasa de velocidad. 2) Variación de la velocidad en función del tiempo. Se utiliza en la ingeniería sísmica para definir el movimiento vibratorio del suelo o de las estrutucturas; se expressa en fracción de gravedad (g) (Material II - IDNDR, 1992)',
#  'D000055': 'Nervio Accesorio Decimoprimer nervio craneal, el cual se origina de las NEURONAS en la MÉDULA y en la MÉDULA ESPINAL cervical. Presenta una raíz craneal que se une al NERVIO VAGO (X craneal) y envía fibras motoras a los músculos de la LARINGE, y una raíz espinal, que envía fibras motoras a los músculos del HUESO TRAPECIO y esternocleidomastoideo.',
#  'D000056': 'Prevención de Accidentes Esfuerzos y proyectos para reducir la incidencia de sucesos indeseables no previstos en distintos ambientes y situaciones.',
#  'D000057': 'Propensión a Accidentes Tendencia a involucrarse en accidentes. Implica ciertas características de personalidad que predisponen a la ocurrencia de accidentes.',
#  'D000058': 'Accidentes por Caídas Caídas causadas por resbalar o tropezar y que pueden producir lesión.',
#  'D000059': 'Accidentes Eventos inesperados y no intencionales, generalmente resultando en LESIONES/TRAUMATISMOS ACCIDENTALES.',
#  'D000060': 'Accidentes de Aviación Eventos imprevistos relacionados con AERONAVES.',
#  'D000061': 'Accidentes Domésticos ACCIDENTES que ocurren en el hogar.',
#  'D000062': 'Accidentes de Trabajo Acontecimientos imprevistos, especialmente lesiones en el curso de las actividades relacionadas con el trabajo.',
#  'D000063': 'Accidentes de Tránsito Accidentes en las calles, caminos, carreteras que involucren a conductores, pasajeros, peatones o vehículos. Los accidentes de tránsito se refieren a los AUTOMÓVILES (carros de pasajeros, autobuses y camiones), BICICLETAS y MOTOCICLETAS, pero no a los VEHÍCULOS MOTORIZADOS RECREACIONALES, TRENES o vehículos para la nieve.',
#  'D000064': 'Aclimatación Adaptación a un nuevo ambiente o a un cambio en el antiguo.',
#  'D000065': 'Acomodación Ocular Ajuste dióptrico del OJO (para lograr la máxima agudeza de imagen en la retina para un objeto que se mira) refiriéndose a la capacidad, al mecanismo o al proceso. La acomodación ocular es efectuar cambios refractivos por cambios en la forma del CRISTALINO. En sentido amplio, se refiere a los ajustes oculares para una VISIÓN OCULAR a diferentes distancias (Adaptación del original: Cline et al., Dictionary of Visual Science, 4th ed.)',
#  'D000066': 'Contabilidad Sistema de registro de transacciones financieras.',
#  'D000066388': 'Industria del Petróleo y Gas INDUSTRIA que se ocupa de la extracción, procesamiento, distribución, comercialización y almacenamiento de PETRÓLEO y GAS NATURAL.',
#  'D000066428': 'Industria del Carbón Empresa asociada a la minería, el procesamiento, al mercadeo y la distribución del CARBÓN MINERAL.',
#  'D000066448': 'Conducir bajo la Influencia Manejar un vehículo de motor bajo los efectos del alcohol u otras drogas, incluyendo las prescritas por los médicos.',
#  'D000066449': 'Células Madre Embrionarias Humanas Tipo de células madre pluripotentes derivadas de embriones humanos en fase inicial, incluyendo la etapa de blastocisto.',
#  'D000066450': 'Células Madre Embrionarias de Ratones CÉLULAS MADRE PLURIPOTENTES derivadas de la MASA CELULAR INTERNA DEL BLASTOCISTO de 3,5 de embriones de ratón.',
#  'D000066473': 'Células Germinales Embrionarias Las células madre pluripotentes que se derivan de las células germinales tempranas.',
#  'D000066477': 'Rendimiento Laboral Medida de que tan bien alguien realiza tareas dada en su lugar de trabajo.',
#  'D000066479': 'Conducta Criminal Conducta que lleva a cometer actos ilícitos.',
#  'D000066491': 'Toma de Decisiones Clínicas Proceso de formulación de un diagnóstico basado en la historia clínica y exámenes físicos o mentales, y / o la elección de una intervención apropiada.',
#  'D000066492': 'Envejecimiento Cognitivo Fenómeno que se produce cuando el aprendizaje y las habilidades de memoria disminuyen de forma natural debido a la edad.',
#  'D000066494': 'Neurociencia Cognitiva Campo de estudio sobre los PROCESOS MENTALES, APRENDIZAJE y las regiones cerebrales asociadas con ellos.',
#  'D000066498': 'Ajuste Emocional Proceso psicológico que ocurre cuando un individuo se adapta a un evento emocional significativo o estímulo.',
#  'D000066499': 'Reconocimiento Facial Capacidad para identificar a una persona e interpretar sus sentimientos y emociones en función de sus expresiones faciales.',
#  'D000066502': 'Abuelos Miembro de una familia que tiene hijos y nietos.',
#  'D000066505': 'Conducta de Búsqueda de Ayuda Forma de comportamiento social en el que se solicita la ayuda de otros.',
#  'D000066506': 'Heurística Técnicas basadas en la experiencia para la resolución de problemas, el aprendizaje y el descubrimiento de que encuentren una solución que no se garantiza que sea óptima, pero suficiente para un determinado conjunto de objetivos.',
#  'D000066511': 'Violencia de Pareja Un patrón de conducta agresiva y coercitiva por un individuo en contra de su pareja o cónyuge que puede incluir daño físico, abuso psicológico, abuso sexual, aislamiento progresivo, acecho, privación, intimidación y la coerción reproductiva.',
#  'D000066530': 'Rehabilitación Neurológica Programas supervisados por médicos diseñados para rehabilitar a las personas con enfermedades, traumatismos o trastornos del SISTEMA NERVIOSO.',
#  'D000066550': 'Abuso Físico Violencia infligida a un individuo a través del contacto físico.',
#  'D000066553': 'Problema de Conducta Mostrar comportamiento molestos o perturbadores.',
#  'D000066608': 'Consumo de Alcohol en Menores El consumo de BEBIDAS ALCOHÓLICAS por menores de la edad legal para beber.',
#  'D000066630': 'Expresión Génica Ectópica La expresión de un gen en un lugar anormal, o en un tiempo anormal en un organismo. Expresión Génica Ectópico se induce a menudo artificialmente mediante técnicas genéticas.',
#  'D000066670': 'Plasticidad de la Célula La capacidad de una célula para cambiar su FENOTIPO en respuesta a los cambios en el medio ambiente.',
#  'D000066673': 'Autorrenovación de las Células Capacidad de ciertos tipos de células, tales como células progenitoras o células tumorales, para atravesar numerosos ciclos de DIVISIÓN CELULAR manteniendo al mismo tiempo un estado indiferenciado o parcialmente diferenciado.',
#  'D000066768': 'Investigación en Rehabilitación Estudios e investigaciones sobre los aspectos psicológicos, educativos, sociales, profesionales, industriales y económicos de la REHABILITACIÓN.',
#  'D000066792': 'Ortodoncistas Dentistas especializados en el tratamiento de los DIENTES mal alineados y MALOCLUSIÓN.',
#  'D000066794': 'Cirujanos Oromaxilofaciales Dentistas que se especializan en el tratamiento quirúrgico de las lesiones, enfermedades y anomalías de las regiones orales y maxilofaciales.',
#  'D000066829': 'Neuroprotección Los procesos fisiológicos y técnicas usadas por el cuerpo para prevenir lesiones neuronales y la degeneración del sistema nervioso central después de trastornos agudos o como resultado de enfermedades neurodegenerativas crónicas.',
#  'D000066888': 'Nutrición, Alimentación y Dieta Conceptos involucrados con la fisiología nutricional, incluyendo las categorías de sustancias consumidas para el sustento, fenómenos y procesos nutricionales, los patrones de alimentación y hábitos, y los parámetros nutricionales medibles.',
#  'D000066889': 'Triticale Planta de grano de cereal, resultado de un cruce entre TRITICUM y SECALE CEREALE.',
#  'D000066891': 'Resultados de Cuidados Críticos Medida de las tasas de mortalidad y morbilidad entre los pacientes que reciben CUIDADOS CRÍTICOS y CUIDADOS INTENSIVOS determinado a partir de la fecha de alta del hospital o la liberación.',
#  'D000066908': 'Entrenamiento Simulado Un medio interactivo altamente personalizadas o programa que permite a las personas aprender y practicar las actividades del mundo real en un entorno preciso, realista, seguro y protegido.',
#  'D000066928': 'Mijos Grupo agronómico en especial de hierbas de semilla pequeña, se cultiva principalmente para el consumo humano y animal.',
#  'D000066949': 'Ciencias Bioconductuales Un enfoque científico interdisciplinario para el estudio de interacciones complejas entre factores biológicos, sociales, conductuales y ambientales.',
#  'D000066970': 'Corona de Proteínas Una capa de recubrimiento de proteína absorbida por NANOPARTÍCULAS a la entrada en el PLASMA u otros fluidos biológicos que contienen proteínas, que afecta a cómo las nanopartículas son internalizados por las células y eliminas del cuerpo.',
#  'D000066988': 'Vegetarianos Personas que no comen CARNE.',
#  'D000066989': 'Veganos Personas que evitan el consumo de productos de origen animal o sustancias de origen animal, como la CARNE, HUEVOS o MIEL. Algunos veganos también se abstengan de utilizar animales o productos de origen animal, en cualquier forma o para cualquier propósito, como en la ROPA o artículos para el hogar.',
#  'D000067': 'Contabilidad de Pagos y Cobros Deudas, obligaciones a corto plazo y bienes en el transcurso regular de transacciones operacionales.',
#  'D000067009': 'Deportes Juveniles Actividades DEPORTIVAS diseñadas y/u organizadas para NIÑOS o JÓVENES.',
#  'D000067010': 'Alfabetización Capacidad para leer y escribir.',
#  'D000067011': 'Desnutrición Aguda Severa Forma aguda de desnutrición que afecta generalmente a los niños, caracterizada por un peso muy bajo para la altura (por debajo de las puntuaciones -3z de los estándares medios de la Organización Mundial de la Salud), emaciación grave visible, o la aparición de EDEMA nutricional. Puede ser una causa directa o indirecta de mortalidad en los niños que sufren de DIARREA y la NEUMONÍA. No debe confundirse con el hambre, una condición en la cual el cuerpo no está recibiendo suficiente alimento, generalmente por períodos prolongados de tiempo.',
#  'D000067012': 'Cuenta Bancaria Una cuenta financiera establecida entre una institución financiera (como un banco comercial) y un cliente (individuo, grupo o empresa), mientras que los últimos pueden depositar y retirar dinero, y en su caso, se pagarán intereses.',
#  'D000067013': 'Diseño de Instalaciones Basado en Evidencias Un enfoque, proceso o metodología que enfatiza evidencia creíble y el mejor conocimiento científico disponible, integrados con prudencia para lograr los mejores resultados posibles en el diseño estructural. Por ejemplo, el diseño de nuevas INSTITUCIONES DE ATENCIÓN AMBULATORIA podría incorporar una revisión de la investigación publicada en el diseño de consultas externas, las decisiones sobre proyectos anteriores similares, junto con entrevistas con el personal y los consumidores.',
#  'D000067029': 'Apariencia Física Apariencias físicas superficiales, las características o cualidades de un individuo se distinguen de la naturaleza o atributos subyacentes invisibles.',
#  'D000067030': 'Jugos de Frutas y Vegetales Los líquidos extraídos de las plantas.',
#  'D000067048': 'Ghee Porción clarificada de leche, crema o mantequilla obtenida por la eliminación de los constituyentes grasos. (Tradução livre do original: Dictionary of Food Ingredients, 4ª ed., 2001)',
#  'D000067071': 'Fracking Hidráulico Una tecnología de perforación en el que el GAS NATURAL se extrae de grandes depósitos de formaciones rocosas impermeables conocidas como esquistos, en lo profundo de la corteza terrestre. Esta técnica de perforación consiste en inyectar grandes volúmenes de fluido a alta presión de fracturación (una mezcla de agua, arena y productos químicos) varios miles de pies bajo tierra, creando así grietas o fisuras en la formación de esquisto, y liberando el gas atrapado.',
#  'D000067073': 'Trauma Psicológico Experiencia emocionalmente dolorosa, impactante, estresante y a veces potencialmente mortal. Puede ser el resultado de presenciar eventos angustiantes como desastres naturales, abuso físico o sexual y terrorismo u otros actos de violencia. (https://www.nimh.nih.gov/health/)',
#  'D000067074': 'Influencia de los Compañeros El efecto o influir en que un GRUPO PARITARIO ejerce sobre las creencias, sistemas de valores y el comportamiento de cada miembro de un grupo. Las expectativas sociales para que los individuos se ajustan a mirar la influencia del grupo se conoce como presión de grupo.',
#  'D000067075': 'Productos Vegetales Alimentos que se fabrica a partir de varias partes de los vegetales.',
#  'D000067088': 'Publicidad Directa al Consumidor Publicidad que se dirige directamente a los consumidores de ciertos productos tales como productos farmacéuticos.',
#  'D000067108': 'Pruebas Dirigidas al Consumidor Las pruebas de laboratorio y los servicios de diagnóstico por imágenes que se ofrecen a los consumidores fuera de la relación médico-paciente.',
#  'D000067128': 'Vesículas Extracelulares Estructuras limitadas de la membrana derivadas de las membranas celulares y del material citoplasmático, liberado al espacio extracelular. Circulan a través del fluido extracelular y a través de la sangre periférica en la microvasculatura, donde las células, mucho más grandes no pueden afectar a una variedad de procesos de comunicación intercelulares.',
#  'D000067148': 'Virus Fúngicos Virus que infectan a especies de hongos.',
#  'D000067170': 'Telocitos Tipo de células intersticiales con muy largas y delgadas EXTENSIONES DE LA SUPERFICIE CELULAR llamados TELÓPODOS.',
#  'D000067190': 'Dispositivo Exoesqueleto Dispositivo diseñado para usar externamente, para apoyar al sistema músculo esquelético en varios movimientos como RANGO DE MOVIMIENTO ; SOPORTE DE PESO ; MARCHA ; y la LOCOMOCIÓN.',
#  'D000067208': 'Hipersensibilidad a los Mariscos Reacción alérgica a los mariscos y productos derivados.',
#  'D000067248': 'Fracaso de Rescate en Atención a la Salud Incapacidad para prevenir un deterioro clínico resultante de una complicación de una condición médica subyacente o una complicación de la atención médica. Esto implica que los factores de riesgos comunes para esta complicación no fueron reconocidos de manera oportuna o el tratamiento apropiado.',
#  'D000067250': 'Rehabilitación Psiquiátrica Campo de especialidad que promueve la recuperación, el funcionamiento de la comunidad, y el aumento de bienestar de los individuos diagnosticados con trastornos mentales que alteran su capacidad de vivir una vida significativa.',
#  'D000067251': 'Brote de los Síntomas Exacerbación transitoria de los síntomas de una enfermedad o afección existente.',
#  'D000067268': 'Preparación de Corazón Aislado Método de aislamiento y mantenimiento de un corazón que trabaja para diversas mediciones cardíacas. El modelo permite la separación de sistémica y cardiaca.',
#  'D000067269': 'Dieta Vegana La práctica dietética de evitar los productos de origen animal en cualquier forma.',
#  'D000067289': 'Técnicas de Observación Conductual Una amplia gama de técnicas formales e informales para documentar el comportamiento.',
#  'D000067290': 'Escala de Evaluación de la Conducta Instrumento diseñado para evaluar el comportamiento humano o animal, utilizando un formato estandarizado.',
#  'D000067292': 'Consumo de Alcohol en la Universidad El consumo de alcohol entre los estudiantes universitarios.',
#  'D000067329': 'Obesidad Metabólica Benigna Sub-FENOTIPO en individuos obesos que tienen riesgo de enfermedades cardiovasculares. También entre individuos sanos con peso normal y las personas saludables con obesidad.',
#  'D000067348': 'Granos Enteros Semillas comestibles que contienen todos los componentes de la semilla: el germen, el salvado y el ENDOSPERMO.',
#  'D000067368': 'Cirugía Endoscópica Transanal Los procedimientos quirúrgicos realizados a través del ano usando un PROCTOSCOPIO.',
#  'D000067369': 'Microcirugía Endoscópica Transanal Una forma especializada de la cirugía endoscópica transanal para operaciones microscópicamente controlados en el RECTO.',
#  'D000067390': 'Lesión por Frío Una lesión física causada por la exposición del cuerpo a temperatura ambiente extremadamente bajas que pueden conducir a la pérdida de partes del cuerpo, o en casos extremos, la muerte. Como ejemplos de lesiones por frío son la congelación y sabañones.',
#  'D000067393': 'Equipo de Protección Personal Ropa o equipo especializado para protección contra riesgos para la salud. El equipo de protección personal puede incluir MASCARAS, DISPOSITIVOS DE PROTECCIÓN RESPIRATORIA, DISPOSITIVOS DE PROTECCIÓN DE LA CABEZA, DISPOSITIVOS DE PROTECCIÓN DE LOS OJOS, DISPOSITIVOS DE PROTECCIÓN DE LOS OÍDOS, ROPA DE PROTECCIÓN y calzado de protección.',
#  'D000067397': 'Agentes Nerviosos Una clase de compuestos que afectan negativamente a la transmisión de los impulsos a través del SISTEMA NERVIOSO.',
#  'D000067398': 'Heridas Relacionadas con la Guerra Heridas, lesiones y traumas psicológicos sufridos durante la guerra.',
#  'D000067399': 'Escala de Movimientos Involuntarios Anormales Una escala de calificación que mide los MOVIMIENTOS INVOLUNTARIOS conocidos como DISCINESIA TARDÍA.',
#  'D000067401': 'Nivel de Alcohol en Sangre Masa de alcohol por unidad de volumen de sangre.',
#  'D000067404': 'Trastorno de Comunicación Social Dificultades persistentes en los usos sociales de la comunicación verbal y no verbal. (DSM-V)',
#  'D000067408': 'Servicios Legales Servicios prestados por ABOGADOS y equipos paralegales.',
#  'D000067448': 'Difamación Declaraciones públicas falsas que son ilegales y perjudiciales para la reputación de una persona, grupo, empresa, organización o institución.',
#  'D000067449': 'Terapia de Manejo de la Ira Sistema de técnicas psicológicas y / o terapéuticos que se utilizan para controlar y reducir los factores desencadenantes o, grados, y los efectos de la IRA.',
#  'D000067450': 'Psicología del Deporte El campo de la investigación que estudia los factores mentales que influyen en el logro de las competencias de atletismo y el rendimiento deportivo.',
#  'D000067453': 'Exposición a la Guerra La salud y otras consecuencias de la exposición militar y civil a la GUERRA.',
#  'D000067454': 'Trastorno de Fluidez de Inicio en la Infancia Las alteraciones en la fluidez y el tiempo del patrón normal del habla que no son apropiados para la edad y habilidades lingüísticas del individuo. (DSM-V)',
#  'D000067455': 'Pacientes no Presentados PACIENTES que no presentan a las citas programadas de salud. No debe confundirse con PACIENTES DESISTENTES DEL TRATAMIENTO.',
#  'D000067470': 'Técnicas de Reprogramación Celular Procedimientos utilizados para la inducción de REPROGRAMACIÓN CELULAR para cambiar el fenotipo de un terminal celular, : tales como la generación de CÉLULAS MADRE PLURIPOTENTES INDUCIDAS diferenciadas a partir de células adultas por la expresión forzada de genes específicos.',
#  'D000067489': 'Metacognición La conciencia y la comprensión de los propios procesos de pensamiento de uno.',
#  'D000067490': 'Uso Excesivo de Medicamentos Recetados El uso de un medicamento en una cantidad más que como prescrito.',
#  'D000067491': 'Near Miss Salud Evento que presenta un riesgo, pero no resulta un daño al paciente.',
#  'D000067492': 'Tratamiento con ARN de Interferencia Una forma de tratamiento de la enfermedad que implica el silenciamiento de genes que están asociados con una enfermedad por el proceso de INTERFERENCIA DE ARN.',
#  'D000067493': 'Dispersión Dinámica de Luz Una técnica analítica para la medición de tamaño de partícula de moléculas que son de menos de una micra de diámetro dispersos o disueltos en un líquido.',
#  'D000067494': 'Pausa de Seguridad en la Atención a la Salud Un período de tiempo fuera del flujo normal de trabajo adoptado para garantizar que detalles claves del procedimiento han sido revisados para una mejor SEGURIDAD DEL PACIENTE y ayudar a prevenir los ERRORES MÉDICOS.',
#  'D000067495': 'Análisis de Modo y Efecto de Fallas en la Atención de la Salud Herramienta prospectivo de evaluación de riesgos destinado a identificar los riesgos potenciales y su impacto en establecimientos de salud.',
#  'D000067496': 'Posesión Espiritual La idea de que el comportamiento anormal o una condición médica es evidencia de que una persona está bajo el control de un poder sobrenatural o espíritu. Esta creencia se llevó a cabo con mayor frecuencia en la religión y la medicina de la época medieval y también se celebra en muchas culturas tribales hoy.',
#  'D000067498': 'Gestión de Recursos de Personal en Salud Parte de la formación relacionada con la salud diseñado para reducir los ERRORES MÉDICOS y mejorar la SEGURIDAD DEL PACIENTE enfatizando trabajo en equipo y los factores humanos (véase la INGENIERÍA HUMANA).',
#  'D000067508': 'Heurística Computacional Métodos de ensayo y error en la resolución de problemas que se utilizan cuando un enfoque algorítmico es impráctico.',
#  'D000067528': 'Ataxinas Una familia de proteínas predominantemente nucleares que regulan la transcripción de genes y la degradación de proteínas. La expansión de repeticiones del trinucleótido CAG en los genes que codifican Ataxinas se asocia con las ATAXIAS ESPINOCEREBELOSAS (AEC). En pacientes de AEC, el número de repeticiones de CAG se correlaciona con la gravedad de la enfermedad e inversamente correlacionada con la edad de aparición de la enfermedad.',
#  'D000067531': 'Alarminas Grupo estructuralmente diverso de moléculas endógenas que son multifuncionales, que tienen funciones fisiológicas dentro de la célula, pero cuando se liberan de células muertas o de células sometidas a estrés o ciertas células inmunitarias, funcionan para activar la INMUNIDAD INNATA. La liberación incontrolada y excesiva de alarmas puede contribuir a la INFLAMACIÓN, CARCINOGENESIS y METASTASIS DE LA NEOPLASIA. Las alarminas son también críticas para la homeostasis del corazón y del tejido nervioso.',
#  'D000067548': 'Rellenos Dérmicos Materiales tales como COLÁGENO o ÁCIDO HIALURÓNICO que se inyectan o se depositan en la dermis para el propósito de aumento de la piel.',
#  'D000067549': 'Espectro de Acción Una técnica utilizada para medir la tasa de actividad fisiológica trazada frente a la longitud de onda de la luz. Un espectro de acción marca la longitud de onda más eficaz de la luz (también conocido como sensibilidad espectral) que se requiere para cada proceso específico.',
#  'D000067551': 'Diplomacia El arte y la práctica de llevar a cabo negociaciones entre las personas, las naciones o de otras partes, como las organizaciones.',
#  'D000067552': 'Acumulación de Mutaciones Concepto que describe los efectos incrementales de MUTACIÓN en los organismos vivos.',
#  'D000067556': "Sitios Internos de Entrada al Ribosoma Secuencias dentro del ARN MENSAJERO que permiten INICIACIÓN DE LA TRADUCCIÓN DE PROTEÍNAS independiente de las CAPERUZAS DE ARN en 5'.",
#  'D000067558': 'Mimetismo Biológico Semejanza en aspecto, estructura, función, sonido, olor o comportamiento entre las especies emparentadas o no, que se producen en la misma ubicación geográfica.',
#  'D000067559': 'Trastorno Específico de Aprendizaje Diagnosticado cuando hay déficits específicos en la capacidad de un individuo para percibir o procesar la información de manera eficiente y precisa. Este trastorno se manifiesta por primera vez durante los años de educación formal y se caracteriza por las dificultades persistentes con el aprendizaje de las habilidades académicas fundamentales en lectura, escritura y / o matemáticas. El desempeño del individuo de las habilidades académicas afectadas es muy por debajo de la media para la edad, o los niveles de desempeño aceptables se logra sólo con un esfuerzo extraordinario. Trastorno del aprendizaje específico puede ocurrir en individuos identificados como dotados intelectualmente y se manifiestan sólo cuando las demandas de aprendizaje o procedimientos de evaluación (por ejemplo, pruebas cronometradas) plantean barreras que no se pueden superar por su inteligencia innata y estrategias compensatorias. Para todas las personas, el trastorno de aprendizaje específica puede producir alteraciones de toda la vida en actividades depende de las habilidades, incluyendo el desempeño ocupacional. (DSM-V)',
#  'D000067561': 'Lista de Medicamentos Potencialmente Inapropiados Una lista, criterios, o herramienta de evaluación diseñada para mejorar la SEGURIDAD DEL PACIENTE determinando la exposición de un individuo a medicamentos potencialmente inapropiados. Están diseñados para prevenir ERRORES DE MEDICACIÓN por PRESCRIPCIÓN INADECUADA. Análisis para la lista que incluye factores como la RELACIÓN DOSIS-RESPUESTA A DROGAS ; EFECTOS COLATERALES Y REACCIONES ADVERSAS RELACIONADAS CON MEDICAMENTOS ; FACTORES DE EDAD ; GÉNERO ; y condiciones médicas existentes.',
#  'D000067562': 'Enfermedades de Inicio Tardío Condiciones patológicas (trastorno, síndrome o enfermedad) cuyos signos y síntomas se manifiestan tarde en la vida de un individuo.',
#  'D000067563': 'Phakopsora pachyrhizi Hongo patógeno que causa la enfermedad de la Roya en la Soja (Glycine max).',
#  'D000067565': 'Agricultores Las personas que cultivan la tierra para los cultivos o criar GANADO.',
#  'D000067568': 'Tecnología Culturalmente Apropiada 1. Una CIENCIA o TECNOLOGÍA que promueve la autosuficiencia y es adecuado a las condiciones culturales, ambientales, económicos y sociales de la zona geográfica en la que se aplica. 2. Tecnología social: El conjunto de técnicas y metodologías transformadoras, desarrolladas y / o aplicadas en la interacción con la población y apropiadas por ella, que representan soluciones para inclusión social y mejora de las condiciones de vida (Traducción libre del original: Instituto de Tecnología Social, 2007. Disponible en: https://www.cidadeescolaaprendiz.org.br/wp-content/uploads/2014/05/conhecimento-e-cidadania_tecnologia_social.pdf). 3. Tecnología social: Dentro del concepto de las tecnologías sociales, es importante subrayar la reaplicabilidad de la tecnología, que ocurre cuando la tecnología social es reinventada y adaptada de acuerdo con la realidad local, teniendo en cuenta el conocimiento y las referencias locales, produciendo de esa forma nuevos resultados, más relevantes y duraderos. (Traducción libre del original: Fonseca, 2008. Disponible en: https://www.arca.fiocruz.br/bitstream/icict/5374/2/1062.pdf).',
#  'D000067570': 'Aprendizaje Social El concepto de la nueva adquisición de conocimientos a través de la observación y la interacción con los demás.',
#  'D000067571': 'Estados Financieros Registro formal y estructurado de la actividades financieras de un negocio, una persona u otra entidad.',
#  'D000067572': 'Mineros Personas que trabajan en una mina para extraer el mineral o MINERALES de la tierra.',
#  'D000067573': 'Cronofarmacocinética Absorción, metabolismo y eliminación de drogas en relación con la hora del día en que se administran y los mecanismos responsables de las variaciones dependientes del tiempo.',
#  'D000067575': 'Reclamos Administrativos en el Cuidado de la Salud La información relativa a la codificación detallada de los procedimientos y los costes asociados a la prestación de asistencia sanitaria, que se utiliza como un medio para el seguimiento de la utilización de servicios de salud, los patrones de atención, y los resultados del tratamiento.',
#  'D000067576': 'Salud del Niño El concepto que abarca las condiciones físicas y mentales de los NIÑOS.',
#  'D000067596': 'Interleucina-33 Miembro de la familia de proteínas INTERLEUCINA-1 implicada en la maduración de CÉLULAS TH2 y la activación de MASTOCITOS, BASÓFILOS, EOSINÓFILOS y CÉLULAS NK. También es producido por las CÉLULAS ENDOTELIALES, CÉLULAS EPITELIALES y FIBROBLASTOS, donde puede funcionar como un alarmina y modular respuestas inmunes e inflamatorias al daño tisular.',
#  'D000067616': 'Proteína S100A12 Miembro de la FAMILIA DE PROTEÍNAS S100 que regula la INFLAMACIÓN y la respuesta inmune. Recluta LEUCOCITOS, promueve la producción de citocinas y quimiocinas y regulan la adhesión y migración de leucocitos. La S100A12 también puede funcionar a través de la unión a los RECEPTORES ESPECÍFICOS DE PRODUCTOS FINALES DE GLUCOSILACIÓN AVANZADA, para estimular las células inmunes innatas.',
#  'D000067617': 'Telopodos Las prolongadas y delgadas superficies de celular de los telocitos que tienen secciones gruesas y delgadas alternadas, llamadas podomos y podómeros.',
#  'D000067636': 'Drosophila simulans Una especie de mosca de la fruta.',
#  'D000067656': 'Optimismo Actitud mental que interpreta los acontecimientos vitales generalmente siendo positivo.',
#  'D000067657': 'Pesimismo La actitud mental que interpreta los acontecimientos vitales generalmente siendo negativo.',
#  'D000067696': 'Ataxina-1 Un factor de unión a la cromatina que reprime la señalización Notch y se asocia con ARN. Ampliación del tracto de poliglutamina por repeticiones CAG en la región codificante del gen ATXN1 está asociada con la ATAXIA ESPINOCEREBELOSA TIPO 1.',
#  'D000067697': 'Salud del Adolescente El concepto que abarca las condiciones físicas y mentales de los ADOLESCENTES.',
#  'D000067698': "Ataxina-2 Una proteína que se une a la región 3' poliadenilada del ARNm que regula negativamente ENDOCITOSIS del EGFR (RECEPTOR DEL FACTOR DE CRECIMIENTO EPIDÉRMICO). Se observa un mayor riesgo de desarrollar ESCLEROSIS LATERAL AMIOTRÓFICA 13 en los pacientes que tienen más de 23 repeticiones CAG en la secuencia de codificación del gen de la ATXN2. En pacientes con ATAXIA ESPINOCEREBELOSA TIPO 2 hay expansiones CAG más largas en el gen de la ATXN2.",
#  'D000067699': 'Ataxina-3 DESUBIQUITINASA de la familia de ATAXINAS. Funciona en la homeostasis de las proteínas, TRANSCRIPCIÓN GENÉTICA; regulación de CITOESQUELETO, y MIOGENESIS. EXPANSIÓN DE REPETICIÓNES DE TRINUCLEÓTIDOS CAG en la región codificante del gen de la ataxina-3 se asocia con ataxia-3 espinocerebelosa (ENFERMEDAD DE MACHADO-JOSEPH).',
#  'D000067716': 'Pruebas en el Punto de Atención Permite diagnósticos de pacientes en el consultorio del médico, en otro ámbito ambulatorio o al lado de la cama. Los resultados de la atención son oportuna, y permiten un tratamiento rápido para el paciente. (Traducción libre del original: NIH Fact Sheet Point-of-Care Diagnostic Testing, 2010)',
#  'D000067719': 'Ataxina-7 Componente del complejo coactivador de la transcripción STAGA-HAT que participa en la activación genética dependiente de CRX (caja homeótica de conos y bastones). También estabiliza los MICROTÚBULOS. La expansión de repeticiones CAG en la región codificante de la ATXN-7 se asocia con el desarrollo de ATAXIA ESPINOCEREBELOSA 7.',
#  'D000067736': 'Ataxina-10 Ataxina que está asociada con la supervivencia de neuronas del cerebelo. Ampliación del pentanucleótido ATTCT en la región de codificación del ATXN10 se asocia a la ataxia espinocerebelosa tipo 10 (ver ATAXIAS ESPINOCEREBELOSAS).',
#  'D000067756': 'Receptores de Péptidos Similares al Glucagón RECEPTORES DE SUPERFICIE CELULAR ACOPLADOS A PROTEÍNAS G que se unen a PÉPTIDOS SIMILARES AL GLUCAGÓN y se expresan por las células en pancreático, intestinal, y los tejidos neuronales. Estos receptores regulan las respuestas celulares a glucosa en sangre, la insulina y señales de inflamación.',
#  'D000067757': 'Receptor del Péptido 1 Similar al Glucagón Un receptor para el PÉPTIDO 1 SIMILAR AL GLUCAGÓN (GLP-1) expresada principalmente en la superficie de beta y células exocrinas ductales del páncreas, así como células de otros tejidos. GLP-1 actúa a través de GLP-1R para potenciar la señalización en las células pancreáticas en respuesta a la secreción de insulina estimulada por glucosa (GSIS).',
#  'D000067758': 'Receptor del Péptido 2 Similar al Glucagón Un receptor para el PÉPTIDO 2 SIMILAR AL GLUCAGÓN (GLP-2) que se expresa en la superficie de las células intestinales, así como las células neuronales. GLP-2 y otros péptidos actúan a través de GLP-2R para regular las respuestas celulares a la GLUCEMIA, INFLAMACIÓN y la INGESTIÓN DE ALIMENTOS.',
#  'D000067759': 'Receptor para Productos Finales de Glicación Avanzada RECEPTORES DE SUPERFICIE CELULAR transmembrana de un solo paso que se une a PRODUCTOS FINALES DE GLICOSILACIÓN AVANZADA para mediar las respuestas celulares a la inflamación vascular aguda y crónica en condiciones tales como ATEROESCLEROSIS y DIABETES MELLITUS TIPO 2. También se une a PÉPTIDOS BETA-AMILOIDES y las ALARMINAS - S100A12 y a la SUBUNIDAD BETA DE LA PROTEÍNA DE UNIÓN AL CALCIO S100.',
#  'D000067776': 'Proteínas con Motivos de Reconocimiento de ARN Familia de PROTEINAS DE UNIÓN AL ARN que contienen un MOTIVO DE RECONOCIMIENTO DE ARN y dos dominios de ribonucleoproteína (RNP) que se unen a RNA, además de otros dominios que permiten alta afinidad vinculante, la especificidad de secuencia, y la proteína interacciones. Ejemplos de proteínas con motivo de reconocimiento de ARN incluyen proteínas RIBONUCLEOPROTEÍNAS NUCLEARES HETEROGÉNEAS (hnRNP) y PROTEÍNAS ELAV.',
#  'D000067777': "Proteína 2 Similar a ELAV Una proteína RRM específicamente neuronal que se une a varias regiones 3'UTR, incluida su propia, así como la de las PROTEÍNAS PROTO-ONCOGÉNICAS C-FOS y PROTEÍNAS INHIBIDORAS DE LA DIFERENCIACIÓN. Se une a través del reconocimiento de un motivo GAA en los ARN.",
#  'D000067778': 'Proteína 3 Similar a ELAV Una proteína neuronal específica RRM que contiene tres motivos de reconocimiento de ARN de tipo RNP (RRM). ELAVL3 humano es reconocido por el anticuerpo del suero anti-Hu de pacientes con encefalomielitis paraneoplásica y neuronopatía sensorial (PEM / PSN). También funciona en la neurogénesis.',
#  'D000067779': "Proteína 4 Similar a ELAV Una proteína de RRM que se une a secuencias ricas en AU en REGIONES NO TRADUCIDAS 3' de los ARNm para PROTEÍNAS PROTO-ONCOGÉNICAS C-FOS ; INHIBIDOR P21 DE LAS QUINASAS DEPENDIENTES DE LA CICLINA ; y la PROTEÍNA GAP-43. Funciona en el procesamiento específico del ARN de neuronas.",
#  'D000067780': "Proteína 1 Similar a ELAV Una proteína de RRM que se une a la región 3'-UTR de los ARNm aumentando su estabilidad. En las CÉLULAS MADRE EMBRIONARIAS, se une a los elementos de poli-U y elementos AU-ricos (AREs) en la 3'-UTR del ARNm objetivo, preferentemente de aquellos ARNm que no están metilados por N6-metiladenosina (m6A), estabilizándolos y promoviendo la diferenciación.",
#  'D000067796': 'Suero Lácteo Se han eliminado los componentes líquidos de la leche que permanecen después de la CASEÍNAS, la grasa y los componentes solubles en grasa. También es un subproducto de la producción de queso.',
#  'D000067816': 'Proteína de Suero de Leche Los componentes de la proteína de leche obtenida a partir del suero.',
#  'D000067836': 'Trastorno de Acumulación Trastorno del comportamiento asociado con dificultades o deterioro clínicamente significativos en áreas sociales, ocupacionales u otras áreas importantes de funcionamiento y dificultad persistente para separarse de las posesiones debido a una necesidad percibida de guardar los artículos y la angustia asociada con descartarlos. (Traducción libre del original: DSM-V) La cantidad de artículos recogidos establece el comportamiento aparte de los comportamientos normales de recolección.',
#  'D000067856': 'Inhibidores de Poli(ADP-Ribosa) Polimerasas[Poly(ADP-ribose) Polymerase Inhibitors] Químicos y fármacos que inhiben la acción de la POLI (ADP-RIBOSA) POLIMERASAS.',
#  'D000067877': 'Trastorno del Espectro Autista Amplia continuidad de cognitivo asociado y los trastornos neuroconductuales, incluyendo, pero no limitado a, tres características principales que definen : deficiencias en la socialización, las deficiencias en la comunicación verbal y no verbal, y los patrones de comportamiento restringidos y repetitivos. (DSM-V)',
#  'D000067878': 'Proteínas CELF Una familia de proteínas RRM que contienen dos dominios N-terminales de motivos de reconocimiento de ARN (RRM) un dominio RRM un C-terminal, y un segmento divergente de 160-230 aminoácidos entre el segundo y tercer dominios RRM. Regulan el EMPALME ALTERNATIVO del pre-ARNm y también funcionan en la EDICIÓN DE ARN y en la BIOSÍNTESIS DE PROTEÍNAS.',
#  'D000067879': "Proteínas CELF1 Miembro de la familia de PROTEÍNAS CELF que, en mamíferos, une elementos ricos en GU (GREs, [GU Rich Elements], o elementos ricos en guanina y uridina) y tripletes repetidos de CUG en las regiones 3'UTR de los ARNm transcritos que se someten a un recambio rápido. También se une a elementos ricos en AU en las REGIONES NO TRADUCIDAS 3' de los ARNm de JUN y FOS. Las mutaciones en el gen CELF1 humana están asociados con DISTROFIA MIOTÓNICA TIPO 1.",
#  'D000067896': 'Desarrollo Industrial Actividad que se ocupa de la planificación y construcción de industrias a través de la fabricación, prestación de servicios especializados, y el COMERCIO.',
#  'D000067917': 'Nube Computacional Almacenamiento de datos y procesamiento de varios servidores que se puede acceder a través de Internet.',
# ...
#  'D000072141': 'Neurólogos Profesionales médicos calificados que se especializan en el tratamiento de ENFERMEDADES DEL SISTEMA NERVIOSO.',
#  'D000072142': 'Patólogos Médicos que evalúan los cambios en la estructura y función celular para diagnosticar los procesos de las enfermedades.',
#  'D000072143': 'Pediatras Profesionales médicos calificados especializados en mantener la salud y brindar atención médica a los niños desde el nacimiento hasta la adolescencia.',
#  'D000072156': 'Neonatólogos Médicos que se especializan en proporcionar atención médica a los recién nacidos.',
#  'D000072157': 'Fisiatras Médicos especializados en el tratamiento de trastornos físicos y lesiones que afectan el cerebro, la médula espinal, los nervios, los huesos, las articulaciones, los ligamentos, los músculos y los tendones.',
#  'D000072158': 'Epidemiólogos Profesionales médicos calificados que estudian las causas, la incidencia y el comportamiento carácterístico de brotes de enfermedades u otras condiciones relacionadas con la salud y determinan las interrelaciones de los hospedadores, agentes y medio ambiente relacionados con la distribución y control de enfermedades.',
#  'D000072159': 'Complejo Dinactina Proteína de múltiples subunidades de CÉLULAS EUCARIOTAS. Funciona en el transporte intracelular bidireccional de los ORGÁNULOS y VESÍCULAS CITOPLASMÁTICAS mediante el enlace a DINEÍNA y CINESINA.',
#  'D000072160': 'Proteína Tumoral p73 Homólogo de PROTEÍNA P53 SUPRESORA DE TUMOR que codifica las isoformas transactivadora y con región N-terminal truncada (DeltaN). La detección de variantes de empalme y isoformas en el sistema nervioso humano (TELENCÉFALO, PLEXO COROIDEO, LÍQUIDO CEFALORRAQUÍDEO), tejido embrionario, NEOPLASIAS DE LA MAMA, NEOPLASIAS OVÁRICAS, sugiere un papel en la diferenciación celular.',
#  'D000072161': 'Cirujanos Ortopédicos Médicos especializados en métodos médicos, quirúrgicos y físicos utilizados para tratar y corregir deformidades, enfermedades y lesiones del sistema esquelético, sus articulaciones y estructuras asociadas.',
#  'D000072162': 'Optometristas Profesionales calificados y capacitados en atención primaria de los ojos y la visión, incluyendo la medición de habilidades visuales, el diagnóstico de trastornos del sistema visual y la prestación de tratamientos, tales como recetas para la corrección de defectos visuales con lentes o gafas y terapia visual.',
#  'D000072163': 'Oftalmólogos Profesionales médicos calificados especializados en el tratamiento médico y quirúrgico de defectos y enfermedades del ojo.',
#  'D000072176': 'Superconductividad Capacidad de un elemento o aleación metálica para permitir el paso de ELECTRONES sin RESISTENCIA ELÉCTRICA y expulsar CAMPOS MAGNÉTICOS por debajo de una determinada temperatura umbral llamada temperatura de transición superconductora.',
#  'D000072177': 'Radiólogos Médicos especializados en el uso de rayos X y otras formas de energía radiante para el diagnóstico y tratamiento de enfermedades.',
#  'D000072178': 'Urólogos Médicos especializados en el diagnóstico y tratamiento de enfermedades del tracto urinario en ambos sexos, y el tracto genital en el hombre.',
#  'D000072179': 'Proteína 1 Similar al Receptor de Interleucina-1 Receptor para la INTERLEUCINA-33 que está relacionada estructuralmente con el receptor de la interleucina-1. Contiene tres regiones de dominios similares a inmunoglobulinas (vease DOMINIOS DE INMUNOGLOBULINA) extracelulares y asociados con la PROTEÍNA ACCESORIA DEL RECEPTOR DE INTERLEUCINA-1 tras la unión de IL-33 para iniciar la señalización. Puede funcionar en la respuesta de LINFOCITOS T COLABORADORES-INDUCTORES a la INFLAMACIÓN.',
#  'D000072180': 'Fosfoinosítido Fosfatasas Fosfatasas que catalizan la hidrólisis de los grupos fosfato en FOSFATIDILINOSITOLES.',
#  'D000072181': "Inositol Polifosfato 5-Fosfatasas Fosfotirosina fosfatasas que catalizan la eliminación del fosfato 5' de INOSITOL 1,4,5-TRIFOSFATO o del mioinositol 1,3,4,5-TETRAFOSFATO, dando como resultado inositol 1,4-bisfosfato y fosfato. Tienen funciones importantes en el metabolismo de FOSFATOS DE INOSITOL y las vías de señalización de inositol 1,4,5-trifosfato tales como la SEÑALIZACIÓN DE CALCIO.",
#  'D000072182': 'Instalaciones Privadas y Públicas no Médicas Espacios y equipos necesarios para una función o servicio no médico utilizado por el público o un grupo específico de personas.',
#  'D000072183': 'Fosfatidilinositol-3,4,5-Trifosfato 5-Fosfatasas Fosfoinositido fosfatasas que catalizan la desfosforilación (hidrólisis) del fosfatidilinositol-3,4,5-trifosfato-3,4,5-(Ptdlns(3,4,5)P(3)) para producir PtdIns(3,4)P(2), que regula negativamente las vías PI3K (PROTEÍNAS QUINASAS DEPENDIENTES DE 3-FOSFOINOSITIDO). Contienen un DOMINIO SH2 y un MOTIVO ALFA ESTÉRIL y tiene funciones importantes en la regulación de la respuesta inmune y otros procesos celulares en los vertebrados.',
#  'D000072184': 'Enfermeras Especialistas Profesionales de enfermería cuya práctica se limita a un área particular o disciplina de la medicina.',
#  'D000072196': 'Fertilinas Proteínas de la superficie del esperma implicadas en la fusión esperma-huevo. Consisten en dos subunidades, fertilina alfa (ADAM1a) y beta (ADAM2), ambas pertenecientes a la familia de proteínas metaloproteasas-desintegrina. La subunidad beta no tiene actividad catalítica.',
#  'D000072197': 'Proteína ADAM10 proteína que contiene un dominio de desintegrina y metaloproteinasa. Divide el precursor ligado a la membrana del FACTOR DE NECROSIS TUMORAL ALFA entre la ALANINA 76 y la VALINA 77 a su forma funcional, así como varias PROTEÍNAS DE SUPERFICIE CELULAR a sus formas solubles, incluyendo el PRECURSOR DE LA PROTEÍNA BETA AMILOIDE y de la PROTEÍNA PRIÓNICA.',
#  'D000072198': 'Proteína ADAM17 Proteína que contiene dominios desintegrina y metaloproteinasa que divide a el precursor ligado a la membrana del FACTOR DE NECROSIS TUMORAL ALFA a su forma madura. Escinde varias otras PROTEÍNAS DE SUPERFICIE CELULAR, incluyendo el RECEPTOR TIPO II DE INTERLEUCINA-1, el FACTOR DE CRECIMIENTO TRANSFORMADOR ALFA, la SELECTINA L, la MUCINA-1 y el PRECURSOR DE PROTEÍNA BETA AMILOIDE. También puede funcionar como un activador de la vía de señalización Notch por mediación de la división de los RECEPTORES NOTCH.',
#  'D000072199': 'Proteína ADAM12 Proteína que contiene dominios de desintegrina y metaloproteinasa que se expresan como dos formas alternativamente empalmadas: una forma transmembrana larga (ADAM12-L) y una forma corta soluble (ADAM12-S). Modula el rompimiento de las PROTEÍNAS DE UNIÓN A FACTOR DE CRECIMIENTO SIMILAR A LA INSULINA y también pueden regular la FUSIÓN CELULAR durante la MIOGÉNESIS.',
#  'D000072200': 'Autoantígeno Ku ADN HELICASA dependiente de ATP que se une preferentemente al ADN DE CADENA SIMPLE. Es un heterodímero que consta de una subunidad 80 kDa (XRCC5) y una subunidad 70 kDa (XRCC6) que funciona con el ADN LIGASA IV en la reparación de las ROTURAS DE LA DOBLE CADENA DEL ADN y en la RECOMBINACIÓN V(D)J.',
#  'D000072216': 'Glicoproteínas de la Zona Pelúcida Glicoproteínas de membrana que constituyen la ZONA PELÚCIDA en mamíferos y función en el reconocimiento y la unión de los ESPERMATOZOIDES.',
#  'D000072218': 'Endodoncistas Dentistas especializados en el tratamiento de lesiones y enfermedades de la PULPA DENTAL.',
#  'D000072219': 'Geriatras Médicos especializados en aspectos fisiológicos y patológicos del envejecimiento y los ancianos, incluyendo los problemas clínicos de senescencia y senilidad.',
#  'D000072220': 'Otorrinolaringólogos Médicos especializados en el tratamiento de trastornos del oído, la nariz y la garganta.',
#  'D000072221': 'Enfermeras Neonatales Profesionales de enfermería calificados especializados en el cuidado de recién nacidos.',
#  'D000072222': 'Enfermeras Pediátricas Profesionales de enfermería calificados especializados en el cuidado de los niños desde el nacimiento hasta a la adolescencia.',
#  'D000072223': 'Alergólogos Médicos especializados en el tratamiento de personas con hipersensibilidad a los ALÉRGENOS.',
#  'D000072224': 'Proteína 11 Similar a Bcl2 Proteína tipo BCL-2 que tiene un dominio C-terminal de homología a BCL-2 (BH3) y forma heterodímeros con otras PROTEÍNAS DE LA FAMILIA BCL-2. Es un potente inductor de la APOPTOSIS y ANOIKIS; varias isoformas se expresan (BimEL, Bim L, Bim-alfa, Bim-s, y Bim-gamma) las que tienen diferentes potencias para la inducción de la apoptosis.',
#  'D000072226': 'Angiografía por Tomografía Computarizada Método no invasivo que utiliza un escáner CT para la captura de imágenes de los vasos sanguíneos y los tejidos. Se inyectan MEDIOS DE CONTRASTE, que ayuda a producir imágenes detalladas que ayudan en el diagnóstico de ENFERMEDADES VASCULARES.',
#  'D000072227': 'Prótesis de Hombro Reemplazo para una ARTICULACIÓN DE HOMBRO.',
#  'D000072228': 'Artroplastía de Reemplazo de Hombro Sustitución de la ARTICULACIÓN DE HOMBRO.',
#  'D000072229': 'Reconstrucción del Ligamento Cruzado Posterior Reconstrucción del LIGAMENTO CRUZADO POSTERIOR para restaurar la estabilidad funcional de la rodilla.',
#  'D000072230': 'Respuesta Virológica Sostenida Supresión continua a largo plazo de la CARGA VIRAL, en general a niveles no detectables, que resulta del tratamiento con ANTIVIRALES.',
#  'D000072231': 'Dosimetría in Vivo Procedimiento para medir la cantidad de radiación absorbida por el cuerpo durante la RADIOTERAPIA por DOSIMETROS en la piel del paciente o cavidades naturales.',
#  'D000072232': 'Dosímetros de Radiación 1) Dispositivos que miden la exposición a la RADIACIÓN IONIZANTE. 2) Instrumento que se emplea para medir y evaluar cualquier magnitud relacionada con la determinación de la dosis de radiactividad absorbida o la dosis equivalente. (Fuente: Material IV - Glosario de Protección Civil, OPS, 1992)',
#  'D000072233': 'Proteínas de Andamiaje Homer Las proteínas Homer pertenecen a una familia de proteínas adaptadoras y andamios que incluyen Homer1, Homer2 y Homer3. Homer1 y Homer2 juegan un papel en la regulación de la homeostasis del calcio, mientras que las funciones HOMER3 en la estimulación de los cambios en la dinámica de la actina en las neuronas y las células T. Las proteínas Homer son mejor conocidos como proteínas de andamiaje en la densidad postsináptica donde facilitan la señalización sináptica. Funcionan como un interruptor molecular en la señalización de receptor metabotrópico de glutamato (mGluR) y se asocian con el síndrome del X frágil humano.',
#  'D000072234': 'Concepción de Donantes Técnicas de reproducción asistida donde se utilizan huevos, esperma, huevos y esperma (doble donación), o embriones de donantes.',
#  'D000072235': 'Factor de Apareamiento Proteína también conocida como factor de feromonas de apareamiento que se produce en las superficies de organismos tales como levaduras y hongos.',
#  'D000072236': 'Proteínas Quimiotácticas Aceptoras de Metilo Proteínas receptoras sensoras de transmembrana que son componentes centrales de los sistemas quimiotácticos de un número de especies de bacterias móviles que incluyen ESCHERICHIA COLI y SALMONELLA TYPHIMURIUM. Proteínas quimiotácticas aceptoras de metilo derivan su nombre de un proceso de adaptación sensorial que implica la metilación en varios residuos de glutamilo en su dominio citoplásmico. Proteínas quimiotácticas de aceptación de metilo estimulan las respuestas quimiotácticas a través de gradientes químicos espaciales, causando en los organismos que se muevan hacia los estímulos favorables o lejos de los que son tóxicos.',
#  'D000072237': 'Canal de Potasio ERG1 Uno de los tres miembros de la familia de genes de los CANALES DE POTASIO éter-a-go-go (EAG) que consta de las subfamilias de genes éter-a-go-go (eag), parecidos a eag (eag-like, elk) y relacionados con eag (eag-related, erg). El gen relacionado con éter-a-go-go 1 (ERG1), también conocido como KCNH2, codifica la subunidad formadora de poro de un canal de potasio rectificador retardado de rápida activación que desempeña un papel esencial en la repolarización final del potencial de acción ventricular. Las mutaciones con pérdida de función en el gen hERG1 humano se asocian a ARRITMIA potencialmente mortal.',
#  'D000072257': 'Capacidad de Absorbancia de Radicales de Oxígeno Medida de la capacidad de una sustancia, tal como un alimento, para absorber los radicales libres de oxígeno in vitro.',
#  'D000072258': 'Hipoxia Tumoral Condiciones hipóxicas en las células tumorales debidas a que el tumor supera su suministro de sangre. Se asocia con aumento de METASTASIS y resistencia a la RADIOTERAPIA y la TRATAMIENTO MEDICAMENTOSO.',
#  'D000072259': 'Conexina 26 Una proteína brecha de la salida codificada por el gen Gap Junction Beta 2 o GJB2. En la cóclea y epidermis, sus hexámeros forman canales entre las células que se pueden abrir para permitir la difusión de célula a célula de moléculas pequeñas, así como el reciclaje de potasio. Las mutaciones en la conexina 26 se asocian con la PÉRDIDA AUDITIVA SENSORINEURAL congénita.',
#  'D000072260': 'Factores de Empalme de ARN Proteínas de unión ARN que facilitan o inhiben el EMPALME DEL ARN.',
#  'D000072261': 'Proteínas Dishevelled Familia de proteínas que son componentes clave de la VÍA DE SEÑALIZACIÓN WNT, donde funcionan hacia abajo de los RECEPTORES FRIZZLED. Contienen un dominio N-terminal de PROTEINA AXINA "disheveled" (DIX), que media la oligomerización, un DOMINIO PDZ central que se une al receptor frizzled y un dominio C-terminal DEP que facilita la unión a la MEMBRANA CELULAR. Las proteínas dishevelled tienen importantes funciones en la DIFERENCIACIÓN CELULAR y en el establecimiento de la POLARIDAD CELULAR.',
#  'D000072263': 'Instalaciones Privadas Lugares diseñados, construídos o instalados para proporcionar una función o servicio específico, no médicos, utilizado por un grupo restringido específico de personas.',
#  'D000072264': 'Instalaciones Deportivas y Recreativas Lugares diseñados, construídos o instalados para ACTIVIDADES RECREATIVAS fuera del hogar.',
#  'D000072277': 'Presiones Respiratorias Máximas Prueba de la función respiratoria que incluye la presión inspiratoria máxima y la presión espiratoria máxima. Se determinó mediante ESPIROMETRÍA, que mide el VOLUMEN RESIDUAL y CAPACIDAD PULMONAR TOTAL del paciente y evalúa la fuerza de los MÚSCULOS RESPIRATORIOS.',
#  'D000072278': 'Proteína Forkhead Box M1 Factor de transcripción box en horquilla que se expresa principalmente en órganos adultos que contienen células proliferantes, tales como: el timo, testículo, ovario, y el intestino delgado. Se controla la expresión de los genes del CICLO CELULAR esenciales para la REPLICACIÓN DEL ADN y la MITOSIS, y las funciones actuales en la REPARACIÓN DEL ADN.',
#  'D000072280': 'Bacterias Termodúricas Bacterias resistentes a altas temperaturas, como las que ocurren en la PASTEURIZACIÓN.',
#  'D000072281': 'Linfadenopatía Enfermedad de los GANGLIOS LINFÁTICOS que son anormales en tamaño, número o consistencia.',
#  'D000072282': 'Escherichia coli Patógena Extraintestinal Cepas de Escherichia coli que poseen rasgos de virulencia que les permiten invadir, colonizar e inducir enfermedades en tejidos fuera del TRACTO GASTROINTESTINAL. Son causa de INFECCIONES URINARIAS (ESCHERICHIA COLI UROPATÓGENA), MENINGITIS neonatal, SEPSIS, NEUMONÍA e INFECCIONES EN LAS HERIDAS QUIRÚRGICAS.',
#  'D000072283': 'Células A549 Una línea celular inmortalizada derivada del ADENOCARCINOMA humano, células epiteliales basales ALVEOLARES aisladas de los pulmones de un paciente masculino en 1972. La línea celular es positiva para QUERATINAS, puede sintetizar LECITINAS y contiene altos niveles de ÁCIDOS GRASOS POLIINSATURADOS en su membrana plasmática. Se utiliza como modelo para la función de los ALVEOLOS PULMONARES y las infecciones virales, como huésped de TRANSFECCIÓN, y para la EVALUACIÓN PRECLINICA DE MEDICAMENTOS.',
#  'D000072296': 'Aparatos Sanitarios Recipientes utilizados para la recolección de excrementos humanos.',
#  ...}

# %% [markdown]
# Si necesitas normalizar y tokenizar los textos existen las funciones `mesinesp2.tokenizer.normalizer()` y `mesinesp2.tokenizer.tokenizer()`. Por ejemplo así tokenizamos los decs y los normalizamos.

# %%
mesinesp2.tokenizer.tokenizer(decs["D000003"], split_sentences=False, is_df = False, normalize = True)
# Out:
# ['mataderos',
#  'lugares',
#  'donde',
#  'los',
#  'animales',
#  'son',
#  'sacrificados',
#  'y',
#  'preparados',
#  'para',
#  'el',
#  'mercado']

# %% [markdown]
# La idea es generar un diccionario que tenga como key el código DeCS y como value el vector que representa ese código, algo como esto.
#
# ```
# {
#    'D000002' : array([0.01, 0.03, ... 0.07, 0.09]) #   El largo del arreglo debiese ser igual a las dimensiones de
#                                                        los embeddings que elijas para representar los códigos
#     ...
# }
# ```

# %%
import numpy as np
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
import nltk
from nltk.corpus import stopwords
stop_words = stopwords.words('spanish')

# %%
for i in decs.keys():
    decs[i] = mesinesp2.tokenizer.tokenizer(decs[i], split_sentences=False, is_df = False, normalize = True)

# %%
for i in decs.keys():
    decs[i] = [word for word in decs[i] if word not in stop_words]

# %%
decs['D000003']
# Out:
# ['mataderos', 'lugares', 'animales', 'sacrificados', 'preparados', 'mercado']

# %% [markdown]
# ### TF-IDF

# %%
import gensim # module for computing word embeddings
import numpy as np # linear algebra module
import sklearn.feature_extraction # package to perform tf-idf vertorization
import json
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def vectorize_text(sentences, idf_location):
    tfidfvectorizer = sklearn.feature_extraction.text.TfidfVectorizer() # instance of the tf-idf vectorizer
    tfidfvectorizer.fit(sentences) # fitting the vectorizer and transforming the properties
    idf = {key:val for key,val in zip(tfidfvectorizer.get_feature_names(),tfidfvectorizer.idf_)}
    with open(idf_location, 'w+', encoding='utf-8') as json_file:
        json.dump(idf, json_file, indent=2, ensure_ascii=False)

# %%
sent = []
for sentence in decs.values():
    sent.append(' '.join(sentence))

# %%
vectorize_text(sent, r'C:/Users/carol/Desktop/Practica 2/tfidf.json')

# %%
with open(r'C:/Users/carol/Desktop/Practica 2/tfidf.json') as f:
    tfidf = json.load(f)

# %% [markdown]
# ### Embeddings

# %%
from gensim.models.keyedvectors import KeyedVectors

# %%
wordvectors_vec = 'fasttext-sbwc.3.6.e20.vec'
cantidad = 100000
wordvectors = KeyedVectors.load_word2vec_format(r'C:\Users\carol\Desktop\Practica 2\SBW-vectors-300-min5.txt', limit = cantidad)

# %%
import fasttext.util

mix = fasttext.load_model(r'C:\Users\carol\Desktop\Practica 2\mix_fasttext.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def to_vector(texto,model,idf):
    """ Receives a sentence string along with a word embedding model and 
    returns the vector representation of the sentence"""
    tokens = texto.split() # splits the text by space and returns a list of words
    vec = np.zeros(300) # creates an empty vector of 300 dimensions
    for word in tokens: # iterates over the sentence
        if (word in model) & (word in idf): # checks if the word is both in the word embedding and the tf-idf model
            vec += model[word]*idf[word] # adds every word embedding to the vector
    if np.linalg.norm(vec) > 0:
        return vec / np.linalg.norm(vec) # divides the vector by their normal
    else:
        return vec

# %%
vectorized_sent_word2vec = [to_vector(text, wordvectors, tfidf) for text in sent]

# %%
dictionary_SBW = {list(decs.keys())[i]: vectorized_sent_word2vec[i].tolist() for i in range(len(list(decs.keys())))}

# %%
vectorized_sent_fasttext = [to_vector(text, mix, tfidf) for text in sent]

# %%
dictionary_mix = {list(decs.keys())[i]: vectorized_sent_fasttext[i].tolist() for i in range(len(list(decs.keys())))}

# %%
with open('decs_sbw.json', 'w') as fp:
    json.dump(dictionary_SBW, fp)

# %%
with open('decs_mix.json', 'w') as fp:
    json.dump(dictionary_mix, fp)
