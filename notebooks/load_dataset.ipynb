# %%
import sys
sys.path.append("..")
import mesinesp2.data

# %%
train, development, test = mesinesp2.data.load_dataset("../data/raw",1)

# %%
train
# Out:
#                   id                                              title  \
# 0         ibc-194909  La resiliencia importa: explicación de la asoc...
# 1       ibc-ET6-1764  La Quercetina como un potencial nutracéutico c...
# 2         ibc-194903  Explorando la perspectiva de los residentes so...
# 3         ibc-195072  Respuesta de un centro de salud ante la pandem...
# 4         ibc-192760  Consecuencias sociolaborales del confinamiento...
# ...              ...                                                ...
# 249469    lil-635226  Operaciones discursivas y contextos argumentat...
# 249470    lil-635227  Relaciones entre recursos humanos y cultura or...
# 249471    lil-635228  Contraste conductual en operantes relacionales...
# 249472    lil-635229  Historia de maltrato físico en la infancia y e...
# 249473    lil-635230  Más allá de la relación terapéutica: un recorr...
#
#                                              abstractText  \
# ...

# %%
development
# Out:
#                   id                                              title  \
# 0     biblio-1000325  Narrativas y significados en torno a la muerte...
# 1     biblio-1001047  Calidad de vida relacionada a la salud y facto...
# 2     biblio-1001056  Estrategia de implementación para la práctica ...
# 3     biblio-1001065  Prevalencia de anticuerpos anti-Saccharomyces ...
# 4     biblio-1001069  Estado actual de las publicaciones científicas...
# ...              ...                                                ...
# 1060    ibc-FGT-2224  Interacciones entre antineoplásicos orales y a...
# 1061    ibc-FGT-2239  Tiempo límite en la velocidad máxima sin calen...
# 1062     ibc-FGT-815  Tratamiento endourológico del muñón ureteral s...
# 1063     ibc-FGT-896  Analgesia mediante bomba de infusión continua ...
# 1064     ibc-FGT-907  Metas de control de la presión arterial e impa...
#
#                                            abstractText  \
# ...

# %%
test
# Out:
#                  id                                              title  \
# 0      ibc-ET1-7180  Tipologías de adhesión al doble estándar sexua...
# 1      ibc-ET1-7181  Combinando técnicas verbales de evaluación de ...
# 2      ibc-ET1-7182  La violencia y la satisfacción laboral de los ...
# 3      ibc-ET1-7183  Redes sociales y acceso online a las drogas: u...
# 4      ibc-ET1-7184  Programas de prevención psicosocial contra la ...
# ...             ...                                                ...
# 10174       02-0107                                     Referencias  1
# 10175       02-0108              gement of anaphylaxis: summary report
# 10176       02-0109                                             59  50
# 10177       02-0110                                             61  85
# 10178       02-0111                                            63  120
#
#                                             abstractText  \
# ...
